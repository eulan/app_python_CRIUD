# %%
from functions import *

# %%
y_code = np.asarray(encoder_frase("mi mama me mima"), )
y_org = np.asarray(num_tranform("mi mama me mima"))

print((np.sum(y_code**2))**.5)
print((np.sum(y_org**2))**.5)
print(np.dot(y_org, y_code))
print((y_code - y_org)%28)
# Out:
# 57.445626465380286
# 56.52433104425032
# 2096
# [21 21 21 21 21 21 21 21 21 21 21 21 21 21 21]

# %%
y = [np.sum((y_code - i)**2) for i in range(-28,28)]
x = [i for i in range(-28,28)]

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.plot(x,y)

# %%
    
print(tranform_palabras("mi mama me mima"))
# Out:
# {'a': 3, 'b': 0, 'c': 0, 'd': 0, 'e': 1, 'f': 0, 'g': 0, 'h': 0, 'i': 2, 'j': 0, 'k': 0, 'l': 0, 'm': 6, 'n': 0, 'ñ': 0, 'o': 0, 'p': 0, 'q': 0, 'r': 0, 's': 0, 't': 0, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0, ' ': 3}

# %%
(y_code-10)%28
# Out:
# array([23, 19, 10, 23, 11, 23, 11, 10, 23, 15, 10, 23, 19, 23, 11],
#       dtype=int32)

# %%
frases = scrapping()

correct_pandas = []

for frase in frases:
    correct_pandas.append(tranform_palabras(frase))

y_correct = np.ones(len(correct_pandas))

incorrect_pandas = []

for frase in frases:
    incorrect_pandas.append(tranform_palabras(num2char_transform(encoder_frase(frase))))
        
y_incorrect = np.zeros(len(incorrect_pandas))

# %%
X_correct = pd.DataFrame(correct_pandas).iloc[:,:27]
y_correct = pd.DataFrame(y_correct)
X_incorrect = pd.DataFrame(incorrect_pandas).iloc[:,:27]
y_incorrect = pd.DataFrame(y_incorrect)
X = pd.concat([X_correct,X_incorrect])
X = (X-X.min())/(X.max()-X.min())
y = pd.concat([y_correct,y_incorrect])

Data = pd.concat([X,y], axis = 1)
Data
# Out:
#             a         b         c         d         e         f         g  \
# 0    0.021277  0.076923  0.076923  0.117647  0.000000  0.000000  0.000000
# 1    1.000000  0.307692  1.000000  0.941176  1.000000  0.176471  0.222222
# 2    0.170213  0.000000  0.384615  0.117647  0.277778  0.058824  0.000000
# 3    0.319149  0.153846  0.076923  0.294118  0.333333  0.000000  0.111111
# 4    0.297872  0.000000  0.384615  0.117647  0.333333  0.058824  0.111111
# ..        ...       ...       ...       ...       ...       ...       ...
# 289  0.000000  0.000000  0.153846  0.117647  0.000000  0.117647  0.000000
# 290  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 291  0.021277  0.076923  0.076923  0.000000  0.000000  0.000000  0.000000
# 292  0.297872  0.153846  0.538462  0.235294  0.444444  0.117647  0.111111
# 293  0.127660  0.000000  0.384615  0.294118  0.222222  0.000000  0.333333
#
#             h         i       j  ...         r         s         t         u  \
# 0    0.000000  0.090909  0.0000  ...  0.000000  0.000000  0.000000  0.090909
# 1    0.052632  1.000000  0.0000  ...  1.000000  0.327869  0.276596  1.000000
# 2    0.000000  0.090909  0.0000  ...  0.277778  0.147541  0.106383  0.363636
# 3    0.052632  0.318182  0.0000  ...  0.333333  0.262295  0.170213  0.363636
# 4    0.000000  0.136364  0.0000  ...  0.333333  0.229508  0.148936  0.454545
# ..        ...       ...     ...  ...       ...       ...       ...       ...
# 289  0.000000  0.045455  0.0000  ...  0.111111  0.016393  0.000000  0.090909
# 290  0.052632  0.000000  0.0000  ...  0.000000  0.000000  0.000000  0.000000
# 291  0.105263  0.000000  0.0625  ...  0.000000  0.000000  0.000000  0.000000
# 292  0.000000  0.409091  0.0625  ...  0.611111  0.262295  0.085106  0.636364
# 293  0.105263  0.272727  0.0000  ...  0.277778  0.131148  0.063830  0.090909
#
#             v    w         x      y         z    0
# 0    0.000000  0.0  0.000000  0.000  0.000000  1.0
# 1    0.178571  0.0  0.027778  0.250  0.142857  1.0
# 2    0.000000  0.0  0.000000  0.125  0.000000  1.0
# 3    0.071429  0.0  0.027778  0.125  0.000000  1.0
# 4    0.000000  0.0  0.000000  0.125  0.000000  1.0
# ..        ...  ...       ...    ...       ...  ...
# 289  0.000000  0.0  0.027778  0.125  0.142857  0.0
# 290  0.000000  1.0  0.027778  0.000  0.142857  0.0
# 291  0.000000  0.0  0.000000  0.250  0.142857  0.0
# 292  0.000000  0.0  0.000000  0.250  0.000000  0.0
# 293  0.107143  0.0  0.000000  0.375  0.000000  0.0
#
# [588 rows x 28 columns]

# %%
from sklearn.datasets import load_iris
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

param_grid = { 'criterion':['gini','entropy'],'max_depth': np.arange(3, 15)}

clf = GridSearchCV(tree.DecisionTreeClassifier(), parameters) 
clf = clf.fit(X_train, y_train)
print(clf.get_params())
# Out:
# {'cv': None, 'error_score': nan, 'estimator__ccp_alpha': 0.0, 'estimator__class_weight': None, 'estimator__criterion': 'gini', 'estimator__max_depth': None, 'estimator__max_features': None, 'estimator__max_leaf_nodes': None, 'estimator__min_impurity_decrease': 0.0, 'estimator__min_impurity_split': None, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__min_weight_fraction_leaf': 0.0, 'estimator__presort': 'deprecated', 'estimator__random_state': None, 'estimator__splitter': 'best', 'estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best'), 'iid': 'deprecated', 'n_jobs': None, 'param_grid': {'max_depth': range(3, 20)}, 'pre_dispatch': '2*n_jobs', 'refit': True, 'return_train_score': False, 'scoring': None, 'verbose': 0}

# %%
tree.plot_tree(clf)
# Out:
# [Text(209.1046875, 209.6742857142857, 'X[4] <= 0.042\ngini = 0.499\nsamples = 393\nvalue = [205, 188]'),
#  Text(120.9, 194.14285714285714, 'X[24] <= 0.014\ngini = 0.332\nsamples = 200\nvalue = [158, 42]'),
#  Text(111.60000000000001, 178.61142857142858, 'X[17] <= 0.025\ngini = 0.453\nsamples = 121\nvalue = [79, 42]'),
#  Text(83.7, 163.07999999999998, 'X[23] <= 0.018\ngini = 0.498\nsamples = 75\nvalue = [35, 40]'),
#  Text(74.4, 147.54857142857142, 'X[14] <= 0.038\ngini = 0.444\nsamples = 60\nvalue = [20, 40]'),
#  Text(55.800000000000004, 132.01714285714286, 'X[7] <= 0.105\ngini = 0.343\nsamples = 50\nvalue = [11, 39]'),
#  Text(46.5, 116.48571428571428, 'X[15] <= 0.026\ngini = 0.282\nsamples = 47\nvalue = [8, 39]'),
#  Text(27.900000000000002, 100.9542857142857, 'X[0] <= 0.011\ngini = 0.484\nsamples = 17\nvalue = [7, 10]'),
#  Text(18.6, 85.42285714285714, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(37.2, 85.42285714285714, 'X[20] <= 0.043\ngini = 0.355\nsamples = 13\nvalue = [3, 10]'),
#  Text(27.900000000000002, 69.89142857142858, 'X[3] <= 0.029\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(18.6, 54.359999999999985, 'X[20] <= 0.011\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(9.3, 38.82857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(27.900000000000002, 38.82857142857142, 'X[2] <= 0.038\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(18.6, 23.29714285714286, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(37.2, 23.29714285714286, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(37.2, 54.359999999999985, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(46.5, 69.89142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(65.10000000000001, 100.9542857142857, 'X[3] <= 0.088\ngini = 0.064\nsamples = 30\nvalue = [1, 29]'),
#  Text(55.800000000000004, 85.42285714285714, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]'),
#  Text(74.4, 85.42285714285714, 'X[25] <= 0.062\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(65.10000000000001, 69.89142857142858, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(83.7, 69.89142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(65.10000000000001, 116.48571428571428, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(93.0, 132.01714285714286, 'X[19] <= 0.041\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(83.7, 116.48571428571428, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(102.30000000000001, 116.48571428571428, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(93.0, 147.54857142857142, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(139.5, 163.07999999999998, 'X[19] <= 0.098\ngini = 0.083\nsamples = 46\nvalue = [44, 2]'),
#  Text(120.9, 147.54857142857142, 'X[13] <= 0.036\ngini = 0.044\nsamples = 44\nvalue = [43, 1]'),
#  Text(111.60000000000001, 132.01714285714286, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]'),
#  Text(130.20000000000002, 132.01714285714286, 'X[8] <= 0.023\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(120.9, 116.48571428571428, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(139.5, 116.48571428571428, 'X[0] <= 0.011\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(130.20000000000002, 100.9542857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(148.8, 100.9542857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(158.10000000000002, 147.54857142857142, 'X[23] <= 0.036\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(148.8, 132.01714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(167.4, 132.01714285714286, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(130.20000000000002, 178.61142857142858, 'gini = 0.0\nsamples = 79\nvalue = [79, 0]'),
#  Text(297.30937500000005, 194.14285714285714, 'X[23] <= 0.018\ngini = 0.368\nsamples = 193\nvalue = [47, 146]'),
#  Text(288.00937500000003, 178.61142857142858, 'X[5] <= 0.088\ngini = 0.27\nsamples = 174\nvalue = [28, 146]'),
#  Text(269.11875000000003, 163.07999999999998, 'X[17] <= 0.125\ngini = 0.198\nsamples = 162\nvalue = [18, 144]'),
#  Text(259.81875, 147.54857142857142, 'X[24] <= 0.014\ngini = 0.152\nsamples = 157\nvalue = [13, 144]'),
#  Text(231.3375, 132.01714285714286, 'X[10] <= 0.028\ngini = 0.112\nsamples = 151\nvalue = [9, 142]'),
#  Text(202.275, 116.48571428571428, 'X[12] <= 0.192\ngini = 0.09\nsamples = 148\nvalue = [7, 141]'),
#  Text(172.05, 100.9542857142857, 'X[11] <= 0.225\ngini = 0.08\nsamples = 144\nvalue = [6, 138]'),
#  Text(139.5, 85.42285714285714, 'X[4] <= 0.069\ngini = 0.069\nsamples = 140\nvalue = [5, 135]'),
#  Text(102.30000000000001, 69.89142857142858, 'X[15] <= 0.079\ngini = 0.142\nsamples = 39\nvalue = [3, 36]'),
#  Text(83.7, 54.359999999999985, 'X[11] <= 0.075\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(74.4, 38.82857142857142, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(93.0, 38.82857142857142, 'X[2] <= 0.038\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(83.7, 23.29714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(102.30000000000001, 23.29714285714286, 'X[7] <= 0.026\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(93.0, 7.765714285714267, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(111.60000000000001, 7.765714285714267, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(120.9, 54.359999999999985, 'X[3] <= 0.088\ngini = 0.074\nsamples = 26\nvalue = [1, 25]'),
#  Text(111.60000000000001, 38.82857142857142, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(130.20000000000002, 38.82857142857142, 'X[2] <= 0.038\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(120.9, 23.29714285714286, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(139.5, 23.29714285714286, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(176.70000000000002, 69.89142857142858, 'X[0] <= 0.117\ngini = 0.039\nsamples = 101\nvalue = [2, 99]'),
#  Text(158.10000000000002, 54.359999999999985, 'X[16] <= 0.167\ngini = 0.02\nsamples = 97\nvalue = [1, 96]'),
#  Text(148.8, 38.82857142857142, 'gini = 0.0\nsamples = 84\nvalue = [0, 84]'),
#  Text(167.4, 38.82857142857142, 'X[25] <= 0.062\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(158.10000000000002, 23.29714285714286, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(176.70000000000002, 23.29714285714286, 'X[13] <= 0.107\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(167.4, 7.765714285714267, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(186.0, 7.765714285714267, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(195.3, 54.359999999999985, 'X[7] <= 0.026\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(186.0, 38.82857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(204.60000000000002, 38.82857142857142, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(204.60000000000002, 85.42285714285714, 'X[11] <= 0.3\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(195.3, 69.89142857142858, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(213.9, 69.89142857142858, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(232.50000000000003, 100.9542857142857, 'X[1] <= 0.038\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(223.20000000000002, 85.42285714285714, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(241.8, 85.42285714285714, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(260.40000000000003, 116.48571428571428, 'X[13] <= 0.036\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(251.10000000000002, 100.9542857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(269.70000000000005, 100.9542857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(288.3, 132.01714285714286, 'X[0] <= 0.053\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(279.0, 116.48571428571428, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(297.6, 116.48571428571428, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(278.41875000000005, 147.54857142857142, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(306.90000000000003, 163.07999999999998, 'X[4] <= 0.278\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(297.6, 147.54857142857142, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(316.20000000000005, 147.54857142857142, 'X[15] <= 0.789\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(306.90000000000003, 132.01714285714286, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(325.5, 132.01714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(306.609375, 178.61142857142858, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]')]

# %%
from sklearn.metrics import confusion_matrix
y_pred = pd.DataFrame(clf.predict(X_test))

confusion_matrix(y_test, y_pred)
# Out:
# array([[81,  8],
#        [ 8, 98]], dtype=int64)

# %%
import pickle

pkl_filename = "pickle_model.pkl"
with open(pkl_filename, 'wb') as file:
    pickle.dump(clf, file)
    
with open(pkl_filename, 'rb') as file:
    pickle_model = pickle.load(file)

score = pickle_model.score(X_test, y_test)
print("Test score: {0:.2f} %".format(100 * score))
Ypredict = pickle_model.predict(X_test)
# Out:
# Test score: 91.79 %
